# %%
# 段落数据提取
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

filename = 'featured-v4-HS300-2010-2016.csv'
print('start')
df = pd.read_csv(filename,index_col=0)
# df = df[df.security=='000001.XSHE']
df=df[:3000]
df.to_csv('f-01.csv')

# df['prev_c1'] = round((df['close'].shift(periods=1) - df['close'].shift(periods=2)) / df['close'].shift(periods=2),3)
# df['prev_c2'] = round((df['close'].shift(periods=2) - df['close'].shift(periods=3)) / df['close'].shift(periods=3),3)

# df.to_csv(filename)
print('done')
# Out:
# start
# done

# %%
# df['today_c'] = round((df['close']-df['p_close'])/df['p_close'],3)
# df['ma5_pos'] = round((df['close']-df['ma5'])/df['close'],3)
# df['ma5_ma10'] = round((df['ma5']-df['ma10'])/df['ma10'],3)
# df['ma60_pos'] = round((df['close']-df['ma60'])/df['ma60'],3) 

# df['future_c1'] = round((df['close'].shift(periods=-1) - df['close']) / df['close'],3)
# df['future_c2'] = round((df['close'].shift(periods=-2) - df['close']) / df['close'],3)
# df['future_c3'] = round((df['close'].shift(periods=-3) - df['close']) / df['close'],3)
# df['future_c4'] = round((df['close'].shift(periods=-3) - df['close']) / df['close'],3)

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

df = pd.read_csv('f-01.csv',index_col=0)
df.drop(columns=['volume','money','median','hash_close','action'],inplace=True)

# adding features
df['future_c1'] = round((df['close'].shift(periods=-1) - df['close']) / df['close'],3)
df['future_c2'] = round((df['close'].shift(periods=-2) - df['close']) / df['close'],3)
df['future_c3'] = round((df['close'].shift(periods=-3) - df['close']) / df['close'],3)
df['future_c4'] = round((df['close'].shift(periods=-3) - df['close']) / df['close'],3)


# 策略组1 - 5日线上买绿柱 胜率 70% 持仓3天
# df = df[df.ma5_pos>0]
# df = df[df.today_c<0.009]
# df = df[df.ma60_pos>-0.05]
# df = df[df.ma60_pos<0.11]
# df = df[df.ma10_ang<0.25]
# df = df[df.prev_c1>0.006]


# 策略组2 - 5日线下买三连绿 持仓1天
df = df[df.ma5_pos<0.00]
df = df[df.today_c<0]
df = df[df.prev_c1<0]
df = df[df.prev_c2<0]


# print(df.columns)

basefund = 1
error = 0
for i in range(len(df)-1):
    change = df['future_c1'].iloc[i]
    if change<-0.01: error+=1
    basefund *= (1+change)

print("-"*100)
print('basefund:',basefund)
print('total:',len(df))
print('errors:',error)
print('errors rate:', round(error/len(df)*100,2))
print("-"*100)

res = df[['future_c1','future_c2','ma5_pos','prev_c1','today_c','ma5_ma10','ma60_pos','p100_pos', 'ma10_ang','mode_pos']][:50]
res = res.sort_values(by=['future_c1'],ascending=False)
print(res[:50])
# Out:
# ----------------------------------------------------------------------------------------------------
# basefund: 2.15091175111
# total: 273
# errors: 51
# errors rate: 18.68
# ----------------------------------------------------------------------------------------------------
#             future_c1  future_c2  ma5_pos  prev_c1  today_c  ma5_ma10  ma60_pos  p100_pos  ma10_ang  mode_pos
# 2010-12-20      0.028      0.006   -0.017   -0.007   -0.013    -0.002    -0.077     0.000     -0.00     0.667
# 2012-06-12      0.023      0.008   -0.028   -0.002   -0.018    -0.021    -0.093     0.000     -0.15     0.222
# 2010-03-25      0.023      0.057   -0.023   -0.001   -0.023     0.000    -0.012     0.254     -0.09     0.750
# 2010-10-22      0.021      0.007   -0.031   -0.031   -0.018     0.019     0.044     0.310      0.45     0.857
# 2010-02-08      0.020      0.032   -0.017   -0.010   -0.019     0.005    -0.086     0.314     -0.05     0.235
# 2010-04-20      0.018     -0.009   -0.072   -0.088   -0.015    -0.028    -0.120     0.000     -0.25     0.709
# 2012-04-17      0.017      0.025   -0.009   -0.007   -0.013     0.010    -0.025     0.387      0.04     0.667
# 2011-12-15      0.016      0.020   -0.036   -0.004   -0.037    -0.011    -0.076     0.000     -0.02     0.634
# 2012-07-09      0.014      0.010   -0.025   -0.004   -0.028     0.004    -0.063     0.062      0.01     0.429
# 2012-03-07      0.014      0.004   -0.020   -0.019   -0.009     0.006     0.039     0.725      0.14     0.889
# 2010-11-23      0.013      0.024   -0.017   -0.020   -0.007    -0.021    -0.074     0.054     -0.37     0.667
# 2011-06-13      0.013     -0.004   -0.016   -0.002   -0.013    -0.019    -0.052     0.354     -0.26     0.444
# 2011-08-22      0.013     -0.002   -0.021   -0.009   -0.009     0.016    -0.029     0.184     -0.02     0.600
# 2010-05-07      0.010     -0.043   -0.060   -0.075   -0.008    -0.016    -0.172     0.000     -0.13     0.348
# 2012-06-25      0.010      0.006   -0.021   -0.020   -0.010     0.009    -0.067     0.082     -0.03     0.429
# 2011-01-18      0.010     -0.028   -0.034   -0.038   -0.002    -0.005    -0.094     0.000      0.05     0.462
# 2011-05-06      0.009     -0.021   -0.021   -0.007   -0.012    -0.009     0.047     0.662     -0.09     0.846
# 2011-09-26      0.008     -0.002   -0.036   -0.005   -0.035     0.000    -0.052     0.056      0.05     0.571
# 2010-12-30      0.008      0.021   -0.019   -0.011   -0.006    -0.011    -0.100     0.000     -0.08     0.363
# 2011-06-17      0.008      0.025   -0.019   -0.017   -0.006    -0.014    -0.076     0.246     -0.25     0.750
# 2010-02-01      0.007      0.063   -0.023   -0.003   -0.021    -0.014    -0.110     0.308      0.06     0.294
# 2010-09-13      0.005     -0.011   -0.020   -0.002   -0.005    -0.017    -0.081     0.055     -0.16     0.600
# 2011-05-30      0.005     -0.007   -0.014   -0.012   -0.002    -0.002     0.026     0.669      0.00     0.917
# 2012-05-14      0.004     -0.011   -0.013   -0.008   -0.004    -0.015    -0.030     0.375     -0.09     0.600
# 2010-04-08      0.004     -0.022   -0.024   -0.022   -0.012     0.000     0.002     0.306      0.03     1.000
# 2011-08-03      0.002     -0.032   -0.011   -0.011   -0.009    -0.002    -0.019     0.365     -0.13     0.833
# 2012-07-25      0.000      0.008   -0.012   -0.002   -0.010    -0.004    -0.049     0.041     -0.03     0.286
# 2010-01-08      0.000     -0.007   -0.024   -0.011   -0.003    -0.003    -0.058     0.549     -0.18     0.250
# 2010-06-02      0.000      0.005   -0.023   -0.010   -0.005    -0.007    -0.167     0.000     -0.07     0.175
# 2011-11-18      0.000      0.006   -0.018   -0.004   -0.002    -0.016    -0.035     0.183     -0.12     0.333
# 2011-01-17     -0.002      0.008   -0.043   -0.022   -0.038     0.001    -0.095     0.000      0.07     0.600
# 2012-05-09     -0.002     -0.009   -0.022   -0.002   -0.024    -0.005    -0.020     0.463      0.06     0.750
# 2010-09-09     -0.002     -0.007   -0.031   -0.022   -0.024    -0.011    -0.083     0.072      0.02     0.267
# 2011-11-17     -0.002     -0.002   -0.023   -0.026   -0.004    -0.014    -0.035     0.195     -0.10     0.667
# 2010-01-07     -0.003     -0.003   -0.037   -0.017   -0.011     0.008    -0.054     0.557     -0.17     0.333
# 2010-01-28     -0.003     -0.024   -0.020   -0.007   -0.007     0.008    -0.093     0.443      0.02     0.294
# 2011-12-13     -0.004     -0.041   -0.012   -0.002   -0.010     0.001    -0.039     0.073      0.01     0.250
# 2012-05-11     -0.004      0.000   -0.017   -0.002   -0.008    -0.011    -0.027     0.400     -0.04     0.600
# 2010-09-10     -0.005      0.000   -0.026   -0.024   -0.002    -0.010    -0.081     0.068     -0.06     0.833
# 2010-12-29     -0.006      0.002   -0.020   -0.008   -0.011    -0.010    -0.096     0.000     -0.05     0.457
# 2010-01-27     -0.007     -0.010   -0.022   -0.007   -0.007     0.020    -0.087     0.462     -0.01     0.294
# 2012-05-10     -0.008     -0.011   -0.018   -0.024   -0.002    -0.008    -0.021     0.450      0.02     0.800
# 2010-05-06     -0.008      0.002   -0.071   -0.005   -0.075    -0.003    -0.167     0.000     -0.15     0.303
# 2011-08-19     -0.009      0.004   -0.014   -0.018   -0.009     0.020    -0.021     0.265     -0.04     1.000
# 2011-12-12     -0.010     -0.013   -0.006   -0.006   -0.002     0.003    -0.030     0.134      0.01     0.200
# 2012-07-24     -0.010     -0.010   -0.007   -0.002   -0.002    -0.001    -0.041     0.093     -0.03     0.500
# 2011-06-10     -0.013      0.000   -0.008   -0.007   -0.002    -0.021    -0.040     0.408     -0.26     0.500
# 2012-06-11     -0.018      0.004   -0.019   -0.026   -0.002    -0.020    -0.078     0.000     -0.13     0.530
# 2010-01-29     -0.021     -0.014   -0.011   -0.007   -0.003    -0.006    -0.093     0.436      0.03     0.263
# 2011-12-14     -0.037     -0.021   -0.011   -0.010   -0.004    -0.003    -0.041     0.049      0.01     0.300
